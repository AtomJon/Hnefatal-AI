# %%
from enum import Enum

class Piece(Enum):
    EMPTY = 0
    KING = 1
    DEFENDER = 2
    ATTACKER = 3

    def __str__(self):
        if self == Piece.EMPTY:
            return " "
        elif self == Piece.KING:
            return "K"
        elif self == Piece.ATTACKER:
            return "O"
        elif self == Piece.DEFENDER:
            return "X"
        else:
            raise ValueError("Invalid piece type")
        
class Player(Enum):
    ATTACKER = 1
    DEFENDER = 2

    def __eq__(self, other):
        if isinstance(other, Player):
            return self.value == other.value
        return False

    def __str__(self):
        if self == Player.ATTACKER:
            return "Attacker"
        elif self == Player.DEFENDER:
            return "Defender"
        else:
            raise ValueError("Invalid player type")
        
    
    def __contains__(self, piece):
        if not isinstance(piece, Piece):
            return False
        
        if self == Player.DEFENDER:
            return piece == Piece.DEFENDER or piece == Piece.KING
        elif self == Player.ATTACKER:
            return piece == Piece.ATTACKER
        
        return False
        
class Coord():
    def __init__(self, x: int, y: int):
        self.x = x
        self.y = y

    def __eq__(self, other):
        if isinstance(other, Coord):
            return self.x == other.x and self.y == other.y
        return False

class Move():
    def __init__(self, from_pos: Coord, to_pos: Coord):
        self.from_pos = from_pos
        self.to_pos = to_pos

class Game:
    board = []

    def __init__(self):
        self.current_player = None
        self.game_over = False
        self.board = []
        
    def fill_board_13_by_13(self):
        for x in range(13):
            row = []
            for y in range(13):
                if (x == 0 or y == 0 or x == 12 or y == 12) and (x in range(4, 9) or y in range(4, 9)):
                    row.append(Piece.ATTACKER)
                elif ((x == 1 or x == 11) and (y == 6)) or ((y == 1 or y == 11) and (x == 6)):
                    row.append(Piece.ATTACKER)
                elif (x == 6 and y == 6):
                    row.append(Piece.KING)
                elif ((x-6)**2 + (y-6)**2) ** 0.5 < 2:
                    row.append(Piece.DEFENDER)
                elif (x == 4 or x == 8) and y == 6:
                    row.append(Piece.DEFENDER)
                elif (y == 4 or y == 8) and x == 6:
                    row.append(Piece.DEFENDER)
                else:
                    row.append(Piece.EMPTY)
            self.board.append(row)

    def print_board(self):
        for row in self.board:
            print(" ".join(str(piece) for piece in row))
        print()

    def is_game_over(self):
        king_pos = None
        for i, row in enumerate(self.board):
            for j, piece in enumerate(row):
                if piece == Piece.KING:
                    king_pos = (i, j)
                    break
            if king_pos:
                break

        assert king_pos is not None, "King position not found on the board"

        x, y = king_pos
        board = self.board

        # Check if king is in a corner
        if (x, y) in [(0, 0), (0, 12), (12, 0), (12, 12)]:
            return True

        # Directions: up, down, left, right
        dirs = [(-1, 0), (1, 0), (0, -1), (0, 1)]
        attacker_count = 0
        wall_count = 0

        for dx, dy in dirs:
            nx, ny = x + dx, y + dy
            if 0 <= nx < 13 and 0 <= ny < 13:
                if board[nx][ny] == Piece.ATTACKER:
                    attacker_count += 1
            else:
                wall_count += 1

        # Surrounded by attackers on all four sides
        if attacker_count == 4:
            return True

        # Back against wall and surrounded by 3 attackers
        if wall_count == 1 and attacker_count == 3:
            return True

        return False
    
    def piece_at(self, pos: Coord):
        return self.board[pos.x][pos.y]
    
    def is_valid_move(self, from_pos: Coord, to_pos: Coord):
        assert all(0 <= element < 13 for element in [from_pos.x, from_pos.y, to_pos.x, to_pos.y]), "Coordinates must be between 0 and 12"

        if from_pos == to_pos:
            return False 
        
        piece = self.piece_at(from_pos)
        if piece == Piece.EMPTY:
            return False
        
        if self.piece_at(to_pos) != Piece.EMPTY:
            return False
        
        if from_pos.x == to_pos.x:
            row = self.board[from_pos.x]
            if from_pos.y < to_pos.y:
                leftmost = from_pos.y + 1
                rightmost = to_pos.y
            else:
                leftmost = to_pos.y
                rightmost = from_pos.y - 1

            for piece in row[leftmost:rightmost]:
                if piece != Piece.EMPTY:
                    return False                                                                                                                                                                                              
        
        elif from_pos.y == to_pos.y:
            if from_pos.x < to_pos.x:
                leftmost = from_pos.x + 1
                rightmost = to_pos.x
            else:
                leftmost = to_pos.x
                rightmost = from_pos.x - 1

            for piece in self.board[to_pos.x][leftmost:rightmost]:
                if piece != Piece.EMPTY:
                    return False   
        else:
            return False
        
        return True
    
    def move_piece(self, from_pos: Coord, to_pos: Coord):
        piece = self.piece_at(from_pos)
        self.board[to_pos.x][to_pos.y] = piece
        self.board[from_pos.x][from_pos.y] = Piece.EMPTY

# %%
def test_game_initialization():
    g = Game()
    assert hasattr(g, 'board')
    assert isinstance(g.board, list)
    assert hasattr(g, 'is_game_over')

def test_fill_board_13_by_13_content():
    g = Game()
    g.fill_board_13_by_13()
    assert len(g.board) == 13
    assert all(len(row) == 13 for row in g.board)
    # Check King position
    assert g.board[6][6] == Piece.KING
    # Check that attackers and defenders are present
    attackers = sum(piece == Piece.ATTACKER for row in g.board for piece in row)
    defenders = sum(piece == Piece.DEFENDER for row in g.board for piece in row)
    assert attackers == 24
    assert defenders == 12

def test_print_board_runs():
    g = Game()
    g.fill_board_13_by_13()
    try:
        g.print_board()
    except Exception as e:
        assert False, f"print_board raised an exception: {e}"

def test_is_valid_move():
    g = Game()
    g.fill_board_13_by_13()

    # Valid horizontal move for defender
    from_pos = Coord(6, 4)
    to_pos = Coord(6, 2)
    assert g.is_valid_move(from_pos, to_pos) is True, "Expected valid horizontal move for defender"

    # Valid vertical move for defender
    from_pos.x, from_pos.y = 6, 4
    to_pos.x, to_pos.y = 10, 4
    assert g.is_valid_move(from_pos, to_pos) is True, "Expected valid vertical move for defender"

    # Invalid move: moving to same position
    from_pos.x, from_pos.y = 6, 5
    to_pos.x, to_pos.y = 6, 5
    assert g.is_valid_move(from_pos, to_pos) is False, "Expected invalid move to same position"

    # Invalid move: moving diagonally
    from_pos.x, from_pos.y = 6, 4
    to_pos.x, to_pos.y = 5, 3
    assert g.is_valid_move(from_pos, to_pos) is False, "Expected invalid diagonal move"

    # Invalid move: blocked by piece
    from_pos.x, from_pos.y = 6, 2
    to_pos.x, to_pos.y = 6, 8
    assert g.is_valid_move(from_pos, to_pos) is False, "Expected invalid move due to blocking piece"

    # Invalid move: moving to occupied position
    from_pos.x, from_pos.y = 6, 4
    to_pos.x, to_pos.y = 6, 1
    assert g.is_valid_move(from_pos, to_pos) is False, "Expected invalid move to occupied position"

def test_move_piece():
    g = Game()
    g.fill_board_13_by_13()
    from_pos = Coord(6, 4)
    to_pos = Coord(6, 2)
    g.move_piece(from_pos, to_pos)
    assert g.piece_at(to_pos) == Piece.DEFENDER, "Expected piece to be moved to new position"
    assert g.piece_at(from_pos) == Piece.EMPTY, "Expected original position to be empty after move"

def test_piece_equality():
    assert Piece.ATTACKER in Player.ATTACKER
    assert Piece.DEFENDER in Player.DEFENDER
    assert Piece.KING in Player.DEFENDER
    assert Piece.EMPTY not in Player.ATTACKER
    assert Piece.EMPTY not in Player.DEFENDER
    assert Piece.ATTACKER not in Player.DEFENDER

test_game_initialization()
test_fill_board_13_by_13_content()
test_print_board_runs()
test_is_valid_move()
test_move_piece()
test_piece_equality()
# Out:
#         O O O O O
#             O
#
#
# O           X           O
# O         X X X         O
# O O     X X K X X     O O
# O         X X X         O
# O           X           O
#
#
#             O
#         O O O O O

# %%
import random

def find_random_move(game: Game, player: Player):
    valid_from_positions = [Coord(x, y) for x, row in enumerate(game.board) for y, piece in enumerate(row) if piece in player]
    assert len(valid_from_positions) > 0, "No valid from positions found"
    from_pos = random.choice(valid_from_positions)

    valid_to_positions = [Coord(x, y) for x in range(13) for y in range(13) if game.is_valid_move(from_pos, Coord(x, y))]
    to_pos = random.choice(valid_to_positions)

    return Move(from_pos, to_pos)
        

def single_game():
    game = Game()
    game.fill_board_13_by_13()
    game.print_board()

    player = Player.DEFENDER  # Defender starts the game
    print(f"Starting game with player: {player}")

    while not game.is_game_over():
        move = find_random_move(game, player)
        print(f"Moving piece from {move.from_pos.x},{move.from_pos.y} to {move.to_pos.x},{move.to_pos.y}")
        game.move_piece(move.from_pos, move.to_pos)
        game.print_board()

        player = Player.ATTACKER if player == Player.DEFENDER else Player.DEFENDER
    
    print("Game over!")

single_game()
# Out:
#         O O O O O
#             O
#
#
# O           X           O
# O         X X X         O
# O O     X X K X X     O O
# O         X X X         O
# O           X           O
#
#
#             O
#         O O O O O
#
# Starting game with player: Defender
# Moving piece from 5,6 to 10,6
#         O O O O O
#             O
#
#
# O           X           O
# O         X   X         O
# O O     X X K X X     O O
# O         X X X         O
# O           X           O
#
#             X
#             O
#         O O O O O
#
# Moving piece from 6,11 to 5,11
#         O O O O O
#             O
#
#
# O           X           O
# O         X   X       O O
# O O     X X K X X       O
# O         X X X         O
# O           X           O
#
#             X
#             O
#         O O O O O
#
# Moving piece from 7,7 to 11,7
#         O O O O O
#             O
#
#
# O           X           O
# O         X   X       O O
# O O     X X K X X       O
# O         X X           O
# O           X           O
#
#             X
#             O X
#         O O O O O
#
# Moving piece from 12,4 to 12,3
#         O O O O O
#             O
#
#
# O           X           O
# O         X   X       O O
# O O     X X K X X       O
# O         X X           O
# O           X           O
#
#             X
#             O X
#       O   O O O O
#
# Moving piece from 6,8 to 10,8
#         O O O O O
#             O
#
#
# O           X           O
# O         X   X       O O
# O O     X X K X         O
# O         X X           O
# O           X           O
#
#             X   X
#             O X
#       O   O O O O
#
# Moving piece from 0,5 to 4,5
#         O   O O O
#             O
#
#
# O         O X           O
# O         X   X       O O
# O O     X X K X         O
# O         X X           O
# O           X           O
#
#             X   X
#             O X
#       O   O O O O
#
# Moving piece from 11,7 to 11,10
#         O   O O O
#             O
#
#
# O         O X           O
# O         X   X       O O
# O O     X X K X         O
# O         X X           O
# O           X           O
#
#             X   X
#             O       X
#       O   O O O O
#
# Moving piece from 0,4 to 0,0
# O           O O O
#             O
#
#
# O         O X           O
# O         X   X       O O
# O O     X X K X         O
# O         X X           O
# O           X           O
#
#             X   X
#             O       X
#       O   O O O O
#
# Moving piece from 6,5 to 8,5
# O           O O O
#             O
#
#
# O         O X           O
# O         X   X       O O
# O O     X   K X         O
# O         X X           O
# O         X X           O
#
#             X   X
#             O       X
#       O   O O O O
#
# Moving piece from 0,8 to 9,8
# O           O O
#             O
#
#
# O         O X           O
# O         X   X       O O
# O O     X   K X         O
# O         X X           O
# O         X X           O
#                 O
#             X   X
#             O       X
#       O   O O O O
#
# Moving piece from 10,6 to 10,1
# O           O O
#             O
#
#
# O         O X           O
# O         X   X       O O
# O O     X   K X         O
# O         X X           O
# O         X X           O
#                 O
#   X             X
#             O       X
#       O   O O O O
#
# Moving piece from 5,11 to 1,11
# O           O O
#             O         O
#
#
# O         O X           O
# O         X   X         O
# O O     X   K X         O
# O         X X           O
# O         X X           O
#                 O
#   X             X
#             O       X
#       O   O O O O
#
# Moving piece from 8,5 to 8,2
# O           O O
#             O         O
#
#
# O         O X           O
# O         X   X         O
# O O     X   K X         O
# O         X X           O
# O   X       X           O
#                 O
#   X             X
#             O       X
#       O   O O O O
#
# Moving piece from 11,6 to 11,1
# O           O O
#             O         O
#
#
# O         O X           O
# O         X   X         O
# O O     X   K X         O
# O         X X           O
# O   X       X           O
#                 O
#   X             X
#   O                 X
#       O   O O O O
#
# Moving piece from 5,7 to 5,8
# O           O O
#             O         O
#
#
# O         O X           O
# O         X     X       O
# O O     X   K X         O
# O         X X           O
# O   X       X           O
#                 O
#   X             X
#   O                 X
#       O   O O O O
#
# Moving piece from 6,0 to 3,0
# O           O O
#             O         O
#
# O
# O         O X           O
# O         X     X       O
#   O     X   K X         O
# O         X X           O
# O   X       X           O
#                 O
#   X             X
#   O                 X
#       O   O O O O
#
# Moving piece from 10,8 to 10,11
# O           O O
#             O         O
#
# O
# O         O X           O
# O         X     X       O
#   O     X   K X         O
# O         X X           O
# O   X       X           O
#                 O
#   X                   X
#   O                 X
#       O   O O O O
#
# Moving piece from 4,5 to 4,3
# O           O O
#             O         O
#
# O
# O     O     X           O
# O         X     X       O
#   O     X   K X         O
# O         X X           O
# O   X       X           O
#                 O
#   X                   X
#   O                 X
#       O   O O O O
#
# Moving piece from 5,5 to 10,5
# O           O O
#             O         O
#
# O
# O     O     X           O
# O               X       O
#   O     X   K X         O
# O         X X           O
# O   X       X           O
#                 O
#   X       X           X
#   O                 X
#       O   O O O O
#
# Moving piece from 0,6 to 0,4
# O       O     O
#             O         O
#
# O
# O     O     X           O
# O               X       O
#   O     X   K X         O
# O         X X           O
# O   X       X           O
#                 O
#   X       X           X
#   O                 X
#       O   O O O O
#
# Moving piece from 7,5 to 2,5
# O       O     O
#             O         O
#           X
# O
# O     O     X           O
# O               X       O
#   O     X   K X         O
# O           X           O
# O   X       X           O
#                 O
#   X       X           X
#   O                 X
#       O   O O O O
#
# Moving piece from 0,4 to 1,4
# O             O
#         O   O         O
#           X
# O
# O     O     X           O
# O               X       O
#   O     X   K X         O
# O           X           O
# O   X       X           O
#                 O
#   X       X           X
#   O                 X
#       O   O O O O
#
# Moving piece from 8,2 to 3,2
# O             O
#         O   O         O
#           X
# O   X
# O     O     X           O
# O               X       O
#   O     X   K X         O
# O           X           O
# O           X           O
#                 O
#   X       X           X
#   O                 X
#       O   O O O O
#
# Moving piece from 4,3 to 2,3
# O             O
#         O   O         O
#       O   X
# O   X
# O           X           O
# O               X       O
#   O     X   K X         O
# O           X           O
# O           X           O
#                 O
#   X       X           X
#   O                 X
#       O   O O O O
#
# Moving piece from 3,2 to 3,5
# O             O
#         O   O         O
#       O   X
# O         X
# O           X           O
# O               X       O
#   O     X   K X         O
# O           X           O
# O           X           O
#                 O
#   X       X           X
#   O                 X
#       O   O O O O
#
# Moving piece from 12,5 to 11,5
# O             O
#         O   O         O
#       O   X
# O         X
# O           X           O
# O               X       O
#   O     X   K X         O
# O           X           O
# O           X           O
#                 O
#   X       X           X
#   O       O         X
#       O     O O O
#
# Moving piece from 10,11 to 10,9
# O             O
#         O   O         O
#       O   X
# O         X
# O           X           O
# O               X       O
#   O     X   K X         O
# O           X           O
# O           X           O
#                 O
#   X       X       X
#   O       O         X
#       O     O O O
#
# Moving piece from 5,12 to 5,11
# O             O
#         O   O         O
#       O   X
# O         X
# O           X           O
# O               X     O
#   O     X   K X         O
# O           X           O
# O           X           O
#                 O
#   X       X       X
#   O       O         X
#       O     O O O
#
# Moving piece from 5,8 to 5,4
# O             O
#         O   O         O
#       O   X
# O         X
# O           X           O
# O       X             O
#   O     X   K X         O
# O           X           O
# O           X           O
#                 O
#   X       X       X
#   O       O         X
#       O     O O O
#
# Moving piece from 12,6 to 12,4
# O             O
#         O   O         O
#       O   X
# O         X
# O           X           O
# O       X             O
#   O     X   K X         O
# O           X           O
# O           X           O
#                 O
#   X       X       X
#   O       O         X
#       O O     O O
#
# Moving piece from 10,1 to 9,1
# O             O
#         O   O         O
#       O   X
# O         X
# O           X           O
# O       X             O
#   O     X   K X         O
# O           X           O
# O           X           O
#   X             O
#           X       X
#   O       O         X
#       O O     O O
#
# Moving piece from 6,12 to 3,12
# O             O
#         O   O         O
#       O   X
# O         X             O
# O           X           O
# O       X             O
#   O     X   K X
# O           X           O
# O           X           O
#   X             O
#           X       X
#   O       O         X
#       O O     O O
#
# Moving piece from 4,6 to 4,10
# O             O
#         O   O         O
#       O   X
# O         X             O
# O                   X   O
# O       X             O
#   O     X   K X
# O           X           O
# O           X           O
#   X             O
#           X       X
#   O       O         X
#       O O     O O
#
# Moving piece from 12,4 to 12,1
# O             O
#         O   O         O
#       O   X
# O         X             O
# O                   X   O
# O       X             O
#   O     X   K X
# O           X           O
# O           X           O
#   X             O
#           X       X
#   O       O         X
#   O   O       O O
#
# Moving piece from 6,4 to 3,4
# O             O
#         O   O         O
#       O   X
# O       X X             O
# O                   X   O
# O       X             O
#   O         K X
# O           X           O
# O           X           O
#   X             O
#           X       X
#   O       O         X
#   O   O       O O
#
# Moving piece from 3,0 to 1,0
# O             O
# O       O   O         O
#       O   X
#         X X             O
# O                   X   O
# O       X             O
#   O         K X
# O           X           O
# O           X           O
#   X             O
#           X       X
#   O       O         X
#   O   O       O O
#
# Moving piece from 10,5 to 10,7
# O             O
# O       O   O         O
#       O   X
#         X X             O
# O                   X   O
# O       X             O
#   O         K X
# O           X           O
# O           X           O
#   X             O
#               X   X
#   O       O         X
#   O   O       O O
#
# Moving piece from 7,0 to 6,0
# O             O
# O       O   O         O
#       O   X
#         X X             O
# O                   X   O
# O       X             O
# O O         K X
#             X           O
# O           X           O
#   X             O
#               X   X
#   O       O         X
#   O   O       O O
#
# Moving piece from 4,10 to 4,9
# O             O
# O       O   O         O
#       O   X
#         X X             O
# O                 X     O
# O       X             O
# O O         K X
#             X           O
# O           X           O
#   X             O
#               X   X
#   O       O         X
#   O   O       O O
#
# Moving piece from 12,3 to 11,3
# O             O
# O       O   O         O
#       O   X
#         X X             O
# O                 X     O
# O       X             O
# O O         K X
#             X           O
# O           X           O
#   X             O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 3,4 to 2,4
# O             O
# O       O   O         O
#       O X X
#           X             O
# O                 X     O
# O       X             O
# O O         K X
#             X           O
# O           X           O
#   X             O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 2,3 to 6,3
# O             O
# O       O   O         O
#         X X
#           X             O
# O                 X     O
# O       X             O
# O O   O     K X
#             X           O
# O           X           O
#   X             O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 4,9 to 1,9
# O             O
# O       O   O     X   O
#         X X
#           X             O
# O                       O
# O       X             O
# O O   O     K X
#             X           O
# O           X           O
#   X             O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 9,8 to 9,6
# O             O
# O       O   O     X   O
#         X X
#           X             O
# O                       O
# O       X             O
# O O   O     K X
#             X           O
# O           X           O
#   X         O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 9,1 to 7,1
# O             O
# O       O   O     X   O
#         X X
#           X             O
# O                       O
# O       X             O
# O O   O     K X
#   X         X           O
# O           X           O
#             O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 6,3 to 6,2
# O             O
# O       O   O     X   O
#         X X
#           X             O
# O                       O
# O       X             O
# O O O       K X
#   X         X           O
# O           X           O
#             O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 8,6 to 5,6
# O             O
# O       O   O     X   O
#         X X
#           X             O
# O                       O
# O       X   X         O
# O O O       K X
#   X         X           O
# O                       O
#             O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 1,0 to 3,0
# O             O
#         O   O     X   O
#         X X
# O         X             O
# O                       O
# O       X   X         O
# O O O       K X
#   X         X           O
# O                       O
#             O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 6,6 to 3,6
# O             O
#         O   O     X   O
#         X X
# O         X K           O
# O                       O
# O       X   X         O
# O O O         X
#   X         X           O
# O                       O
#             O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 0,0 to 2,0
#               O
#         O   O     X   O
# O       X X
# O         X K           O
# O                       O
# O       X   X         O
# O O O         X
#   X         X           O
# O                       O
#             O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 2,5 to 2,6
#               O
#         O   O     X   O
# O       X   X
# O         X K           O
# O                       O
# O       X   X         O
# O O O         X
#   X         X           O
# O                       O
#             O
#               X   X
#   O   O   O         X
#   O           O O
#
# Moving piece from 11,5 to 11,6
#               O
#         O   O     X   O
# O       X   X
# O         X K           O
# O                       O
# O       X   X         O
# O O O         X
#   X         X           O
# O                       O
#             O
#               X   X
#   O   O     O       X
#   O           O O
#
# Moving piece from 7,6 to 0,6
#             X O
#         O   O     X   O
# O       X   X
# O         X K           O
# O                       O
# O       X   X         O
# O O O         X
#   X                     O
# O                       O
#             O
#               X   X
#   O   O     O       X
#   O           O O
#
# Moving piece from 6,2 to 6,4
#             X O
#         O   O     X   O
# O       X   X
# O         X K           O
# O                       O
# O       X   X         O
# O O     O     X
#   X                     O
# O                       O
#             O
#               X   X
#   O   O     O       X
#   O           O O
#
# Moving piece from 3,5 to 3,2
#             X O
#         O   O     X   O
# O       X   X
# O   X       K           O
# O                       O
# O       X   X         O
# O O     O     X
#   X                     O
# O                       O
#             O
#               X   X
#   O   O     O       X
#   O           O O
#
# Moving piece from 8,0 to 8,2
#             X O
#         O   O     X   O
# O       X   X
# O   X       K           O
# O                       O
# O       X   X         O
# O O     O     X
#   X                     O
#     O                   O
#             O
#               X   X
#   O   O     O       X
#   O           O O
#
# Moving piece from 0,6 to 0,4
#         X     O
#         O   O     X   O
# O       X   X
# O   X       K           O
# O                       O
# O       X   X         O
# O O     O     X
#   X                     O
#     O                   O
#             O
#               X   X
#   O   O     O       X
#   O           O O
#
# Moving piece from 11,1 to 9,1
#         X     O
#         O   O     X   O
# O       X   X
# O   X       K           O
# O                       O
# O       X   X         O
# O O     O     X
#   X                     O
#     O                   O
#   O         O
#               X   X
#       O     O       X
#   O           O O
#
# Moving piece from 11,10 to 12,10
#         X     O
#         O   O     X   O
# O       X   X
# O   X       K           O
# O                       O
# O       X   X         O
# O O     O     X
#   X                     O
#     O                   O
#   O         O
#               X   X
#       O     O
#   O           O O   X
#
# Moving piece from 6,4 to 3,4
#         X     O
#         O   O     X   O
# O       X   X
# O   X   O   K           O
# O                       O
# O       X   X         O
# O O           X
#   X                     O
#     O                   O
#   O         O
#               X   X
#       O     O
#   O           O O   X
#
# Moving piece from 7,1 to 7,4
#         X     O
#         O   O     X   O
# O       X   X
# O   X   O   K           O
# O                       O
# O       X   X         O
# O O           X
#         X               O
#     O                   O
#   O         O
#               X   X
#       O     O
#   O           O O   X
#
# Moving piece from 7,12 to 7,10
#         X     O
#         O   O     X   O
# O       X   X
# O   X   O   K           O
# O                       O
# O       X   X         O
# O O           X
#         X           O
#     O                   O
#   O         O
#               X   X
#       O     O
#   O           O O   X
#
# Moving piece from 5,4 to 5,3
#         X     O
#         O   O     X   O
# O       X   X
# O   X   O   K           O
# O                       O
# O     X     X         O
# O O           X
#         X           O
#     O                   O
#   O         O
#               X   X
#       O     O
#   O           O O   X
#
# Moving piece from 3,0 to 8,0
#         X     O
#         O   O     X   O
# O       X   X
#     X   O   K           O
# O                       O
# O     X     X         O
# O O           X
#         X           O
# O   O                   O
#   O         O
#               X   X
#       O     O
#   O           O O   X
#
# Moving piece from 10,7 to 10,1
#         X     O
#         O   O     X   O
# O       X   X
#     X   O   K           O
# O                       O
# O     X     X         O
# O O           X
#         X           O
# O   O                   O
#   O         O
#   X               X
#       O     O
#   O           O O   X
#
# Moving piece from 8,2 to 8,8
#         X     O
#         O   O     X   O
# O       X   X
#     X   O   K           O
# O                       O
# O     X     X         O
# O O           X
#         X           O
# O               O       O
#   O         O
#   X               X
#       O     O
#   O           O O   X
#
# Moving piece from 7,4 to 7,6
#         X     O
#         O   O     X   O
# O       X   X
#     X   O   K           O
# O                       O
# O     X     X         O
# O O           X
#             X       O
# O               O       O
#   O         O
#   X               X
#       O     O
#   O           O O   X
#
# Moving piece from 9,1 to 9,4
#         X     O
#         O   O     X   O
# O       X   X
#     X   O   K           O
# O                       O
# O     X     X         O
# O O           X
#             X       O
# O               O       O
#         O   O
#   X               X
#       O     O
#   O           O O   X
#
# Moving piece from 5,3 to 5,5
#         X     O
#         O   O     X   O
# O       X   X
#     X   O   K           O
# O                       O
# O         X X         O
# O O           X
#             X       O
# O               O       O
#         O   O
#   X               X
#       O     O
#   O           O O   X
#
# Moving piece from 11,3 to 12,3
#         X     O
#         O   O     X   O
# O       X   X
#     X   O   K           O
# O                       O
# O         X X         O
# O O           X
#             X       O
# O               O       O
#         O   O
#   X               X
#             O
#   O   O       O O   X
#
# Moving piece from 1,9 to 4,9
#         X     O
#         O   O         O
# O       X   X
#     X   O   K           O
# O                 X     O
# O         X X         O
# O O           X
#             X       O
# O               O       O
#         O   O
#   X               X
#             O
#   O   O       O O   X
#
# Moving piece from 4,0 to 1,0
#         X     O
# O       O   O         O
# O       X   X
#     X   O   K           O
#                   X     O
# O         X X         O
# O O           X
#             X       O
# O               O       O
#         O   O
#   X               X
#             O
#   O   O       O O   X
#
# Moving piece from 6,7 to 6,11
#         X     O
# O       O   O         O
# O       X   X
#     X   O   K           O
#                   X     O
# O         X X         O
# O O                   X
#             X       O
# O               O       O
#         O   O
#   X               X
#             O
#   O   O       O O   X
#
# Moving piece from 6,1 to 6,7
#         X     O
# O       O   O         O
# O       X   X
#     X   O   K           O
#                   X     O
# O         X X         O
# O             O       X
#             X       O
# O               O       O
#         O   O
#   X               X
#             O
#   O   O       O O   X
#
# Moving piece from 6,11 to 6,8
#         X     O
# O       O   O         O
# O       X   X
#     X   O   K           O
#                   X     O
# O         X X         O
# O             O X
#             X       O
# O               O       O
#         O   O
#   X               X
#             O
#   O   O       O O   X
#
# Moving piece from 8,12 to 9,12
#         X     O
# O       O   O         O
# O       X   X
#     X   O   K           O
#                   X     O
# O         X X         O
# O             O X
#             X       O
# O               O
#         O   O           O
#   X               X
#             O
#   O   O       O O   X
#
# Moving piece from 10,1 to 10,6
#         X     O
# O       O   O         O
# O       X   X
#     X   O   K           O
#                   X     O
# O         X X         O
# O             O X
#             X       O
# O               O
#         O   O           O
#             X     X
#             O
#   O   O       O O   X
#
# Moving piece from 0,7 to 0,9
#         X         O
# O       O   O         O
# O       X   X
#     X   O   K           O
#                   X     O
# O         X X         O
# O             O X
#             X       O
# O               O
#         O   O           O
#             X     X
#             O
#   O   O       O O   X
#
# Moving piece from 4,9 to 4,2
#         X         O
# O       O   O         O
# O       X   X
#     X   O   K           O
#     X                   O
# O         X X         O
# O             O X
#             X       O
# O               O
#         O   O           O
#             X     X
#             O
#   O   O       O O   X
#
# Moving piece from 12,3 to 11,3
#         X         O
# O       O   O         O
# O       X   X
#     X   O   K           O
#     X                   O
# O         X X         O
# O             O X
#             X       O
# O               O
#         O   O           O
#             X     X
#       O     O
#   O           O O   X
#
# Moving piece from 4,2 to 4,1
#         X         O
# O       O   O         O
# O       X   X
#     X   O   K           O
#   X                     O
# O         X X         O
# O             O X
#             X       O
# O               O
#         O   O           O
#             X     X
#       O     O
#   O           O O   X
#
# Moving piece from 8,8 to 8,4
#         X         O
# O       O   O         O
# O       X   X
#     X   O   K           O
#   X                     O
# O         X X         O
# O             O X
#             X       O
# O       O
#         O   O           O
#             X     X
#       O     O
#   O           O O   X
#
# Moving piece from 2,4 to 4,4
#         X         O
# O       O   O         O
# O           X
#     X   O   K           O
#   X     X               O
# O         X X         O
# O             O X
#             X       O
# O       O
#         O   O           O
#             X     X
#       O     O
#   O           O O   X
#
# Moving piece from 12,7 to 12,3
#         X         O
# O       O   O         O
# O           X
#     X   O   K           O
#   X     X               O
# O         X X         O
# O             O X
#             X       O
# O       O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 6,8 to 5,8
#         X         O
# O       O   O         O
# O           X
#     X   O   K           O
#   X     X               O
# O         X X   X     O
# O             O
#             X       O
# O       O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 8,4 to 7,4
#         X         O
# O       O   O         O
# O           X
#     X   O   K           O
#   X     X               O
# O         X X   X     O
# O             O
#         O   X       O
# O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 3,2 to 5,2
#         X         O
# O       O   O         O
# O           X
#         O   K           O
#   X     X               O
# O   X     X X   X     O
# O             O
#         O   X       O
# O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 7,4 to 7,3
#         X         O
# O       O   O         O
# O           X
#         O   K           O
#   X     X               O
# O   X     X X   X     O
# O             O
#       O     X       O
# O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 5,6 to 5,7
#         X         O
# O       O   O         O
# O           X
#         O   K           O
#   X     X               O
# O   X     X   X X     O
# O             O
#       O     X       O
# O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 2,0 to 3,0
#         X         O
# O       O   O         O
#             X
# O       O   K           O
#   X     X               O
# O   X     X   X X     O
# O             O
#       O     X       O
# O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 5,8 to 3,8
#         X         O
# O       O   O         O
#             X
# O       O   K   X       O
#   X     X               O
# O   X     X   X       O
# O             O
#       O     X       O
# O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 1,11 to 0,11
#         X         O   O
# O       O   O
#             X
# O       O   K   X       O
#   X     X               O
# O   X     X   X       O
# O             O
#       O     X       O
# O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 2,6 to 6,6
#         X         O   O
# O       O   O
#
# O       O   K   X       O
#   X     X               O
# O   X     X   X       O
# O           X O
#       O     X       O
# O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 1,0 to 1,3
#         X         O   O
#       O O   O
#
# O       O   K   X       O
#   X     X               O
# O   X     X   X       O
# O           X O
#       O     X       O
# O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 0,4 to 0,7
#               X   O   O
#       O O   O
#
# O       O   K   X       O
#   X     X               O
# O   X     X   X       O
# O           X O
#       O     X       O
# O
#         O   O           O
#             X     X
#       O     O
#   O   O         O   X
#
# Moving piece from 11,3 to 2,3
#               X   O   O
#       O O   O
#       O
# O       O   K   X       O
#   X     X               O
# O   X     X   X       O
# O           X O
#       O     X       O
# O
#         O   O           O
#             X     X
#             O
#   O   O         O   X
#
# Moving piece from 6,6 to 5,6
#               X   O   O
#       O O   O
#       O
# O       O   K   X       O
#   X     X               O
# O   X     X X X       O
# O             O
#       O     X       O
# O
#         O   O           O
#             X     X
#             O
#   O   O         O   X
#
# Moving piece from 3,12 to 0,12
#               X   O   O O
#       O O   O
#       O
# O       O   K   X
#   X     X               O
# O   X     X X X       O
# O             O
#       O     X       O
# O
#         O   O           O
#             X     X
#             O
#   O   O         O   X
#
# Moving piece from 0,7 to 0,3
#       X           O   O O
#       O O   O
#       O
# O       O   K   X
#   X     X               O
# O   X     X X X       O
# O             O
#       O     X       O
# O
#         O   O           O
#             X     X
#             O
#   O   O         O   X
#
# Moving piece from 7,10 to 6,10
#       X           O   O O
#       O O   O
#       O
# O       O   K   X
#   X     X               O
# O   X     X X X       O
# O             O     O
#       O     X
# O
#         O   O           O
#             X     X
#             O
#   O   O         O   X
#
# Moving piece from 7,6 to 7,5
#       X           O   O O
#       O O   O
#       O
# O       O   K   X
#   X     X               O
# O   X     X X X       O
# O             O     O
#       O   X
# O
#         O   O           O
#             X     X
#             O
#   O   O         O   X
#
# Moving piece from 6,0 to 6,5
#       X           O   O O
#       O O   O
#       O
# O       O   K   X
#   X     X               O
# O   X     X X X       O
#           O   O     O
#       O   X
# O
#         O   O           O
#             X     X
#             O
#   O   O         O   X
#
# Moving piece from 3,6 to 2,6
#       X           O   O O
#       O O   O
#       O     K
# O       O       X
#   X     X               O
# O   X     X X X       O
#           O   O     O
#       O   X
# O
#         O   O           O
#             X     X
#             O
#   O   O         O   X
#
# Moving piece from 9,12 to 9,10
#       X           O   O O
#       O O   O
#       O     K
# O       O       X
#   X     X               O
# O   X     X X X       O
#           O   O     O
#       O   X
# O
#         O   O       O
#             X     X
#             O
#   O   O         O   X
#
# Moving piece from 0,3 to 0,5
#           X       O   O O
#       O O   O
#       O     K
# O       O       X
#   X     X               O
# O   X     X X X       O
#           O   O     O
#       O   X
# O
#         O   O       O
#             X     X
#             O
#   O   O         O   X
#
# Moving piece from 5,11 to 5,12
#           X       O   O O
#       O O   O
#       O     K
# O       O       X
#   X     X               O
# O   X     X X X         O
#           O   O     O
#       O   X
# O
#         O   O       O
#             X     X
#             O
#   O   O         O   X
#
# Moving piece from 10,9 to 9,9
#           X       O   O O
#       O O   O
#       O     K
# O       O       X
#   X     X               O
# O   X     X X X         O
#           O   O     O
#       O   X
# O
#         O   O     X O
#             X
#             O
#   O   O         O   X
#
# Moving piece from 9,6 to 9,5
#           X       O   O O
#       O O   O
#       O     K
# O       O       X
#   X     X               O
# O   X     X X X         O
#           O   O     O
#       O   X
# O
#         O O       X O
#             X
#             O
#   O   O         O   X
#
# Moving piece from 4,4 to 5,4
#           X       O   O O
#       O O   O
#       O     K
# O       O       X
#   X                     O
# O   X   X X X X         O
#           O   O     O
#       O   X
# O
#         O O       X O
#             X
#             O
#   O   O         O   X
#
# Moving piece from 8,0 to 11,0
#           X       O   O O
#       O O   O
#       O     K
# O       O       X
#   X                     O
# O   X   X X X X         O
#           O   O     O
#       O   X
#
#         O O       X O
#             X
# O           O
#   O   O         O   X
#
# Moving piece from 0,5 to 0,7
#               X   O   O O
#       O O   O
#       O     K
# O       O       X
#   X                     O
# O   X   X X X X         O
#           O   O     O
#       O   X
#
#         O O       X O
#             X
# O           O
#   O   O         O   X
#
# Moving piece from 1,6 to 1,9
#               X   O   O O
#       O O         O
#       O     K
# O       O       X
#   X                     O
# O   X   X X X X         O
#           O   O     O
#       O   X
#
#         O O       X O
#             X
# O           O
#   O   O         O   X
#
# Moving piece from 9,9 to 9,8
#               X   O   O O
#       O O         O
#       O     K
# O       O       X
#   X                     O
# O   X   X X X X         O
#           O   O     O
#       O   X
#
#         O O     X   O
#             X
# O           O
#   O   O         O   X
#
# Moving piece from 5,0 to 6,0
#               X   O   O O
#       O O         O
#       O     K
# O       O       X
#   X                     O
#     X   X X X X         O
# O         O   O     O
#       O   X
#
#         O O     X   O
#             X
# O           O
#   O   O         O   X
#
# Moving piece from 5,5 to 5,3
#               X   O   O O
#       O O         O
#       O     K
# O       O       X
#   X                     O
#     X X X   X X         O
# O         O   O     O
#       O   X
#
#         O O     X   O
#             X
# O           O
#   O   O         O   X
#
# Moving piece from 0,12 to 2,12
#               X   O   O
#       O O         O
#       O     K           O
# O       O       X
#   X                     O
#     X X X   X X         O
# O         O   O     O
#       O   X
#
#         O O     X   O
#             X
# O           O
#   O   O         O   X
#
# Moving piece from 0,7 to 0,4
#         X         O   O
#       O O         O
#       O     K           O
# O       O       X
#   X                     O
#     X X X   X X         O
# O         O   O     O
#       O   X
#
#         O O     X   O
#             X
# O           O
#   O   O         O   X
#
# Moving piece from 6,0 to 6,1
#         X         O   O
#       O O         O
#       O     K           O
# O       O       X
#   X                     O
#     X X X   X X         O
#   O       O   O     O
#       O   X
#
#         O O     X   O
#             X
# O           O
#   O   O         O   X
#
# Moving piece from 12,10 to 8,10
#         X         O   O
#       O O         O
#       O     K           O
# O       O       X
#   X                     O
#     X X X   X X         O
#   O       O   O     O
#       O   X
#                     X
#         O O     X   O
#             X
# O           O
#   O   O         O
#
# Moving piece from 12,3 to 10,3
#         X         O   O
#       O O         O
#       O     K           O
# O       O       X
#   X                     O
#     X X X   X X         O
#   O       O   O     O
#       O   X
#                     X
#         O O     X   O
#       O     X
# O           O
#   O             O
#
# Moving piece from 8,10 to 8,8
#         X         O   O
#       O O         O
#       O     K           O
# O       O       X
#   X                     O
#     X X X   X X         O
#   O       O   O     O
#       O   X
#                 X
#         O O     X   O
#       O     X
# O           O
#   O             O
#
# Moving piece from 1,4 to 1,2
#         X         O   O
#     O O           O
#       O     K           O
# O       O       X
#   X                     O
#     X X X   X X         O
#   O       O   O     O
#       O   X
#                 X
#         O O     X   O
#       O     X
# O           O
#   O             O
#
# Moving piece from 5,3 to 8,3
#         X         O   O
#     O O           O
#       O     K           O
# O       O       X
#   X                     O
#     X   X   X X         O
#   O       O   O     O
#       O   X
#       X         X
#         O O     X   O
#       O     X
# O           O
#   O             O
#
# Moving piece from 10,3 to 9,3
#         X         O   O
#     O O           O
#       O     K           O
# O       O       X
#   X                     O
#     X   X   X X         O
#   O       O   O     O
#       O   X
#       X         X
#       O O O     X   O
#             X
# O           O
#   O             O
#
# Moving piece from 5,4 to 5,5
#         X         O   O
#     O O           O
#       O     K           O
# O       O       X
#   X                     O
#     X     X X X         O
#   O       O   O     O
#       O   X
#       X         X
#       O O O     X   O
#             X
# O           O
#   O             O
#
# Moving piece from 9,4 to 10,4
#         X         O   O
#     O O           O
#       O     K           O
# O       O       X
#   X                     O
#     X     X X X         O
#   O       O   O     O
#       O   X
#       X         X
#       O   O     X   O
#         O   X
# O           O
#   O             O
#
# Moving piece from 9,8 to 11,8
#         X         O   O
#     O O           O
#       O     K           O
# O       O       X
#   X                     O
#     X     X X X         O
#   O       O   O     O
#       O   X
#       X         X
#       O   O         O
#         O   X
# O           O   X
#   O             O
#
# Moving piece from 6,7 to 8,7
#         X         O   O
#     O O           O
#       O     K           O
# O       O       X
#   X                     O
#     X     X X X         O
#   O       O         O
#       O   X
#       X       O X
#       O   O         O
#         O   X
# O           O   X
#   O             O
#
# Moving piece from 8,8 to 8,9
#         X         O   O
#     O O           O
#       O     K           O
# O       O       X
#   X                     O
#     X     X X X         O
#   O       O         O
#       O   X
#       X       O   X
#       O   O         O
#         O   X
# O           O   X
#   O             O
#
# Moving piece from 0,9 to 0,5
#         X O           O
# ...
#     O       O X       O
#   X       O X
#       O               X X
#   O             X       O
#
# Moving piece from 3,9 to 3,11
#             O O
# K           O       O
#         O       X
#       O   O           X O
#         O     O
#       X   O O   O
#   O
#     X           O O
#     X O X
#     O       O X       O
#   X       O X
#       O               X X
#   O             X       O
#
# Moving piece from 10,5 to 9,5
#             O O
# K           O       O
#         O       X
#       O   O           X O
#         O     O
#       X   O O   O
#   O
#     X           O O
#     X O X
#     O     O O X       O
#   X         X
#       O               X X
#   O             X       O
#
# Moving piece from 10,1 to 10,2
#             O O
# K           O       O
#         O       X
#       O   O           X O
#         O     O
#       X   O O   O
#   O
#     X           O O
#     X O X
#     O     O O X       O
#     X       X
#       O               X X
#   O             X       O
#
# Moving piece from 4,7 to 4,12
#             O O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#       X   O O   O
#   O
#     X           O O
#     X O X
#     O     O O X       O
#     X       X
#       O               X X
#   O             X       O
#
# Moving piece from 8,4 to 7,4
#             O O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#       X   O O   O
#   O
#     X   X       O O
#     X O
#     O     O O X       O
#     X       X
#       O               X X
#   O             X       O
#
# Moving piece from 7,9 to 10,9
#             O O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#       X   O O   O
#   O
#     X   X       O
#     X O
#     O     O O X       O
#     X       X     O
#       O               X X
#   O             X       O
#
# Moving piece from 10,2 to 10,5
#             O O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#       X   O O   O
#   O
#     X   X       O
#     X O
#     O     O O X       O
#           X X     O
#       O               X X
#   O             X       O
#
# Moving piece from 0,7 to 0,4
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#       X   O O   O
#   O
#     X   X       O
#     X O
#     O     O O X       O
#           X X     O
#       O               X X
#   O             X       O
#
# Moving piece from 12,8 to 12,10
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#       X   O O   O
#   O
#     X   X       O
#     X O
#     O     O O X       O
#           X X     O
#       O               X X
#   O                 X   O
#
# Moving piece from 11,3 to 11,0
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#       X   O O   O
#   O
#     X   X       O
#     X O
#     O     O O X       O
#           X X     O
# O                     X X
#   O                 X   O
#
# Moving piece from 10,6 to 6,6
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#       X   O O   O
#   O         X
#     X   X       O
#     X O
#     O     O O X       O
#           X       O
# O                     X X
#   O                 X   O
#
# Moving piece from 5,8 to 5,10
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#       X   O O       O
#   O         X
#     X   X       O
#     X O
#     O     O O X       O
#           X       O
# O                     X X
#   O                 X   O
#
# Moving piece from 12,10 to 12,6
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#       X   O O       O
#   O         X
#     X   X       O
#     X O
#     O     O O X       O
#           X       O
# O                     X X
#   O         X           O
#
# Moving piece from 9,5 to 12,5
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#       X   O O       O
#   O         X
#     X   X       O
#     X O
#     O       O X       O
#           X       O
# O                     X X
#   O       O X           O
#
# Moving piece from 5,3 to 5,1
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#   X       O O       O
#   O         X
#     X   X       O
#     X O
#     O       O X       O
#           X       O
# O                     X X
#   O       O X           O
#
# Moving piece from 5,10 to 5,9
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#   X       O O     O
#   O         X
#     X   X       O
#     X O
#     O       O X       O
#           X       O
# O                     X X
#   O       O X           O
#
# Moving piece from 10,5 to 10,7
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#   X       O O     O
#   O         X
#     X   X       O
#     X O
#     O       O X       O
#               X   O
# O                     X X
#   O       O X           O
#
# Moving piece from 7,8 to 7,10
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#   X       O O     O
#   O         X
#     X   X           O
#     X O
#     O       O X       O
#               X   O
# O                     X X
#   O       O X           O
#
# Moving piece from 11,11 to 11,8
#         O   O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#   X       O O     O
#   O         X
#     X   X           O
#     X O
#     O       O X       O
#               X   O
# O               X       X
#   O       O X           O
#
# Moving piece from 0,4 to 0,2
#     O       O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#   X       O O     O
#   O         X
#     X   X           O
#     X O
#     O       O X       O
#               X   O
# O               X       X
#   O       O X           O
#
# Moving piece from 11,8 to 11,4
#     O       O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#   X       O O     O
#   O         X
#     X   X           O
#     X O
#     O       O X       O
#               X   O
# O       X               X
#   O       O X           O
#
# Moving piece from 8,3 to 9,3
#     O       O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#   X       O O     O
#   O         X
#     X   X           O
#     X
#     O O     O X       O
#               X   O
# O       X               X
#   O       O X           O
#
# Moving piece from 10,7 to 11,7
#     O       O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#   X       O O     O
#   O         X
#     X   X           O
#     X
#     O O     O X       O
#                   O
# O       X     X         X
#   O       O X           O
#
# Moving piece from 9,3 to 7,3
#     O       O
# K           O       O
#         O       X
#       O   O           X O
#         O               O
#   X       O O     O
#   O         X
#     X O X           O
#     X
#     O       O X       O
#                   O
# O       X     X         X
#   O       O X           O
#
# Moving piece from 2,8 to 3,8
#     O       O
# K           O       O
#         O
#       O   O     X     X O
#         O               O
#   X       O O     O
#   O         X
#     X O X           O
#     X
#     O       O X       O
#                   O
# O       X     X         X
#   O       O X           O
#
# Moving piece from 5,9 to 5,12
#     O       O
# K           O       O
#         O
#       O   O     X     X O
#         O               O
#   X       O O           O
#   O         X
#     X O X           O
#     X
#     O       O X       O
#                   O
# O       X     X         X
#   O       O X           O
#
# Moving piece from 11,7 to 10,7
#     O       O
# K           O       O
#         O
#       O   O     X     X O
#         O               O
#   X       O O           O
#   O         X
#     X O X           O
#     X
#     O       O X       O
#               X   O
# O       X               X
#   O       O X           O
#
# Moving piece from 5,12 to 1,12
#     O       O
# K           O       O   O
#         O
#       O   O     X     X O
#         O               O
#   X       O O
#   O         X
#     X O X           O
#     X
#     O       O X       O
#               X   O
# O       X               X
#   O       O X           O
#
# Moving piece from 11,12 to 10,12
#     O       O
# K           O       O   O
#         O
#       O   O     X     X O
#         O               O
#   X       O O
#   O         X
#     X O X           O
#     X
#     O       O X       O
#               X   O     X
# O       X
#   O       O X           O
#
# Moving piece from 12,5 to 8,5
#     O       O
# K           O       O   O
#         O
#       O   O     X     X O
#         O               O
#   X       O O
#   O         X
#     X O X           O
#     X     O
#     O       O X       O
#               X   O     X
# O       X
#   O         X           O
#
# Moving piece from 7,2 to 1,2
#     O       O
# K   X       O       O   O
#         O
#       O   O     X     X O
#         O               O
#   X       O O
#   O         X
#       O X           O
#     X     O
#     O       O X       O
#               X   O     X
# O       X
#   O         X           O
#
# Moving piece from 5,6 to 5,12
#     O       O
# K   X       O       O   O
#         O
#       O   O     X     X O
#         O               O
#   X       O             O
#   O         X
#       O X           O
#     X     O
#     O       O X       O
#               X   O     X
# O       X
#   O         X           O
#
# Moving piece from 11,4 to 8,4
#     O       O
# K   X       O       O   O
#         O
#       O   O     X     X O
#         O               O
#   X       O             O
#   O         X
#       O X           O
#     X   X O
#     O       O X       O
#               X   O     X
# O
#   O         X           O
#
# Moving piece from 4,12 to 2,12
#     O       O
# K   X       O       O   O
#         O               O
#       O   O     X     X O
#         O
#   X       O             O
#   O         X
#       O X           O
#     X   X O
#     O       O X       O
#               X   O     X
# O
#   O         X           O
#
# Moving piece from 1,2 to 11,2
#     O       O
# K           O       O   O
#         O               O
#       O   O     X     X O
#         O
#   X       O             O
#   O         X
#       O X           O
#     X   X O
#     O       O X       O
#               X   O     X
# O   X
#   O         X           O
#
# Moving piece from 3,5 to 6,5
#     O       O
# K           O       O   O
#         O               O
#       O         X     X O
#         O
#   X       O             O
#   O       O X
#       O X           O
#     X   X O
#     O       O X       O
#               X   O     X
# O   X
#   O         X           O
#
# Moving piece from 7,4 to 7,8
#     O       O
# K           O       O   O
#         O               O
#       O         X     X O
#         O
#   X       O             O
#   O       O X
#       O         X   O
#     X   X O
#     O       O X       O
#               X   O     X
# O   X
#   O         X           O
#
# Moving piece from 0,2 to 1,2
#             O
# K   O       O       O   O
#         O               O
#       O         X     X O
#         O
#   X       O             O
#   O       O X
#       O         X   O
#     X   X O
#     O       O X       O
#               X   O     X
# O   X
#   O         X           O
#
# Moving piece from 6,6 to 6,12
#             O
# K   O       O       O   O
#         O               O
#       O         X     X O
#         O
#   X       O             O
#   O       O             X
#       O         X   O
#     X   X O
#     O       O X       O
#               X   O     X
# O   X
#   O         X           O
#
# Moving piece from 10,9 to 12,9
#             O
# K   O       O       O   O
#         O               O
#       O         X     X O
#         O
#   X       O             O
#   O       O             X
#       O         X   O
#     X   X O
#     O       O X       O
#               X         X
# O   X
#   O         X     O     O
#
# Moving piece from 3,8 to 3,10
#             O
# K   O       O       O   O
#         O               O
#       O             X X O
#         O
#   X       O             O
#   O       O             X
#       O         X   O
#     X   X O
#     O       O X       O
#               X         X
# O   X
#   O         X     O     O
#
# Moving piece from 2,4 to 1,4
#             O
# K   O   O   O       O   O
#                         O
#       O             X X O
#         O
#   X       O             O
#   O       O             X
#       O         X   O
#     X   X O
#     O       O X       O
#               X         X
# O   X
#   O         X     O     O
#
# Moving piece from 1,0 to 0,0
# K           O
#     O   O   O       O   O
#                         O
#       O             X X O
#         O
#   X       O             O
#   O       O             X
#       O         X   O
#     X   X O
#     O       O X       O
#               X         X
# O   X
#   O         X     O     O
#
# Game over!
